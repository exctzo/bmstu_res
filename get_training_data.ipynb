# %% [markdown]
# ### Получение данных

# %% [markdown]
# Подключаемые модули

# %%
import os
from io import BytesIO

# %%
import pandas as pd
import pickle
from zipfile import ZipFile
from urllib.request import urlopen, urlretrieve

# %% [markdown]
# Подключение Gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# Загрузка Cisco Umbrella Popularity List (legit)

# %%
if not os.path.isfile('/content/gdrive/My Drive/Colab Notebooks/Res/input data/top-1m.csv'):
    resp = urlopen('http://s3-us-west-1.amazonaws.com/umbrella-static/top-1m.csv.zip')
    zipfile = ZipFile(BytesIO(resp.read()))
    zipfile.extractall("/content/gdrive/My Drive/Colab Notebooks/Res/input data")

# %% [markdown]
# Загрузка Malware Domain by John Bambenek of Bambenek Consulting (dga)

# %%
urlretrieve('http://osint.bambenekconsulting.com/feeds/dga-feed.txt', '/content/gdrive/My Drive/Colab Notebooks/Res/input data/dga.csv')
# Out:
# ('/content/gdrive/My Drive/Colab Notebooks/Res/input data/dga.csv',
#  <http.client.HTTPMessage at 0x7fb6cb7aff28>)

# %% [markdown]
# Конструкция данных обучения

# %%
training_data = {'legit': [], 'dga': []}

# %% [markdown]
# Выделение второго уровная доменного имени

# %%
domain_list = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Res/input data/top-1m.csv', names=['domain'])
domain_list['domain'] = domain_list['domain'].map(lambda x: x.split('.')[-2:]).map(lambda x: x[0])
domain_list['type'] = 0
training_data['legit'] = domain_list

# %%
training_data['legit']
# Out:
#                          domain  type
# 1                       netflix     0
# 2                       netflix     0
# 3                       netflix     0
# 4                       netflix     0
# 5                        google     0
# 6                        google     0
# 7                     microsoft     0
# 8                   doubleclick     0
# 9                       netflix     0
# 10                     facebook     0
# 11                  doubleclick     0
# 12                   googleapis     0
# 13             google-analytics     0
# 14                       google     0
# 15                  doubleclick     0
# 16                         live     0
# 17                    microsoft     0
# 18                        apple     0
# 19                   googleapis     0
# 20                   googleapis     0
# 21             google-analytics     0
# 22                      netflix     0
# 23                    microsoft     0
# 24            googleusercontent     0
# 25                   googleapis     0
# 26                    amazonaws     0
# 27                      youtube     0
# 28                      netflix     0
# 29                     facebook     0
# 30                   googleapis     0
# ...                         ...   ...
# 999971                      com     0
# 999972           biodifferences     0
# 999973                   gatech     0
# 999974         bitcheswhobrunch     0
# 999975                    prlog     0
# 999976                tendawifi     0
# 999977                   vodien     0
# 999978                      com     0
# 999979                     adx1     0
# 999980                 bjsubway     0
# 999981                edgesuite     0
# 999982                 localdns     0
# 999983        blackberryvietnam     0
# 999984                   angelo     0
# 999985            blackbusiness     0
# 999986                wordpress     0
# 999987        blackdemographics     0
# 999988             blacktieskis     0
# 999989                 bladecdn     0
# 999990                    blast     0
# 999991                 belhaven     0
# 999992             blendersavvy     0
# 999993              blockspring     0
# 999994                     aarp     0
# 999995                   fiverr     0
# 999996              foodnetwork     0
# 999997                  myshapa     0
# 999998                     naia     0
# 999999   naturalhealthyconcepts     0
# 1000000             potterybarn     0
#
# [1000000 rows x 2 columns]

# %%
domain_list = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Res/input data/dga.csv', names=['domain', 'family', 'data'], skiprows = 14, index_col=False)
domain_list['domain'] = domain_list['domain'].map(lambda x: x.split('.')[0])
domain_list['family'] = domain_list['family'].map(lambda x: x.split(' ')[3])
domain_list['type'] = 1
training_data['dga'] = domain_list

# %%
training_data['dga']
# Out:
#                 domain          family        data  type
# 0       evwsqtnjxyhvew    Cryptolocker  2019-02-13     1
# 1       rygmaebibpakfy    Cryptolocker  2019-02-13     1
# 2       fmlkdvfdnaxqgd    Cryptolocker  2019-02-13     1
# 3       sqvlaujjnyxnff    Cryptolocker  2019-02-13     1
# 4       gebjdmneajvtws    Cryptolocker  2019-02-13     1
# 5       xumqlbbtyahqte    Cryptolocker  2019-02-13     1
# 6       ywrdkshglmmfdn    Cryptolocker  2019-02-13     1
# 7       ymcplrjuljftbd    Cryptolocker  2019-02-13     1
# 8       aohckjphxvkiby    Cryptolocker  2019-02-13     1
# 9       adqhxtbobkvoft    Cryptolocker  2019-02-13     1
# 10      bfvtwlhbnwbdok    Cryptolocker  2019-02-13     1
# 11      buggxkjpnttrfl    Cryptolocker  2019-02-13     1
# 12      cwlswcpcagygfo    Cryptolocker  2019-02-13     1
# 13      vpjjyhblehwkoj    Cryptolocker  2019-02-13     1
# 14      jdohccoacwkygv    Cryptolocker  2019-02-13     1
# 15      xkyftxjysbesmr    Cryptolocker  2019-02-13     1
# 16      lxedwswnqqrhnr    Cryptolocker  2019-02-13     1
# 17      xxnalabggrlioc    Cryptolocker  2019-02-13     1
# 18      llsxououehywgv    Cryptolocker  2019-02-13     1
# 19      asdvgqjtulsqfj    Cryptolocker  2019-02-13     1
# 20      ngitjlwisbgfgq    Cryptolocker  2019-02-13     1
# 21      ettewwbdeciwgx    Cryptolocker  2019-02-13     1
# 22      fvyqvrqmctxdgw    Cryptolocker  2019-02-13     1
# 23      gojarnjqsvpfer    Cryptolocker  2019-02-13     1
# 24      hqomqiyaqnflnh    Cryptolocker  2019-02-13     1
# 25      gcxujpbxgmwurk    Cryptolocker  2019-02-13     1
# 26      hedhikqheembrq    Cryptolocker  2019-02-13     1
# 27      iwnqegjlugedid    Cryptolocker  2019-02-13     1
# 28      jysddbyusxtjra    Cryptolocker  2019-02-13     1
# 29        dgijxnmginkx    Cryptolocker  2019-02-13     1
# ...                ...             ...         ...   ...
# 835247           knddt  unknowndropper  2019-02-15     1
# 835248           kndtd  unknowndropper  2019-02-15     1
# 835249           kntdd  unknowndropper  2019-02-15     1
# 835250           ktddn  unknowndropper  2019-02-15     1
# 835251           ktdnd  unknowndropper  2019-02-15     1
# 835252           ktndd  unknowndropper  2019-02-15     1
# 835253           nddkt  unknowndropper  2019-02-15     1
# 835254           nddtk  unknowndropper  2019-02-15     1
# 835255           ndkdt  unknowndropper  2019-02-15     1
# 835256           ndktd  unknowndropper  2019-02-15     1
# 835257           ndtdk  unknowndropper  2019-02-15     1
# 835258           ndtkd  unknowndropper  2019-02-15     1
# 835259           nkddt  unknowndropper  2019-02-15     1
# 835260           nkdtd  unknowndropper  2019-02-15     1
# 835261           nktdd  unknowndropper  2019-02-15     1
# 835262           ntddk  unknowndropper  2019-02-15     1
# 835263           ntdkd  unknowndropper  2019-02-15     1
# 835264           ntkdd  unknowndropper  2019-02-15     1
# 835265           tddkn  unknowndropper  2019-02-15     1
# 835266           tddnk  unknowndropper  2019-02-15     1
# 835267           tdkdn  unknowndropper  2019-02-15     1
# 835268           tdknd  unknowndropper  2019-02-15     1
# 835269           tdndk  unknowndropper  2019-02-15     1
# 835270           tdnkd  unknowndropper  2019-02-15     1
# 835271           tkddn  unknowndropper  2019-02-15     1
# 835272           tkdnd  unknowndropper  2019-02-15     1
# 835273           tkndd  unknowndropper  2019-02-15     1
# 835274           tnddk  unknowndropper  2019-02-15     1
# 835275           tndkd  unknowndropper  2019-02-15     1
# 835276           tnkdd  unknowndropper  2019-02-15     1
#
# [835277 rows x 4 columns]

# %% [markdown]
# Сохранение данных на диск

# %%
with open('/content/gdrive/My Drive/Colab Notebooks/Res/input data/training_data.pkl', 'wb') as f:
    pickle.dump(training_data, f, pickle.HIGHEST_PROTOCOL)
